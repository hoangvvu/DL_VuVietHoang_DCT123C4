# %%
# %run calc.py
# Out:
# Đã tải xong các lệnh từ file calc.y!

# %%
so_thu_nhat = 15
so_thu_hai = 5

print(f"Kết quả {so_thu_nhat} + {so_thu_hai} = {cong(so_thu_nhat, so_thu_hai)}")
print(f"Kết quả {so_thu_nhat} - {so_thu_hai} = {tru(so_thu_nhat, so_thu_hai)}")
print(f"Kết quả {so_thu_nhat} x {so_thu_hai} = {nhan(so_thu_nhat, so_thu_hai)}")
print(f"Kết quả {so_thu_nhat} / {so_thu_hai} = {chia(so_thu_nhat, so_thu_hai)}")
# Out:
# Kết quả 15 + 5 = 20
# Kết quả 15 - 5 = 10
# Kết quả 15 x 5 = 75
# Kết quả 15 / 5 = 3.0
